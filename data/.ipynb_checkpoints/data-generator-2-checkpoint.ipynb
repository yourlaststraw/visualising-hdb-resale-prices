# %%
import numpy as np
import pandas as pd
import requests

from bs4 import BeautifulSoup
import requests
import re
from datetime import datetime

# %%
# Define your OneMap API token
api_token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..CxCbdnEqMcGoHGCcTZci8iPVsXV4NHAerK_EDjY7os8'

# Example endpoint URL for geocoding
endpoint = 'https://www.onemap.gov.sg/api/common/elastic/search'

# Example parameters for geocoding
params = {
    'returnGeom': 'Y',
    'getAddrDetails': 'Y',
    'token': api_token,
}

# %% [markdown]
# **MRT Info**

# %%
links = {'MRT':'https://en.wikipedia.org/wiki/List_of_Singapore_MRT_stations', 'LRT':'https://en.wikipedia.org/wiki/List_of_Singapore_LRT_stations'}

# Define a custom filter function
def not_colspan_nine(tag):
    return (tag.name == 'tr' and 
            not tag.find('td', colspan='9') and 
            not tag.find('th'))

MRT_LRT_full_info = pd.DataFrame(columns = ['Station Code', 'Station Name', 'Longitude', 'Latitude', 'Opening Date', 'Station Type'])

row_num = 0

for station_type,link in links.items():
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')

    table = soup.find_all('table', class_="wikitable sortable")[0].find_all('tbody')[0]
    
    # Find all <tr> elements that do not have <td colspan="9">
    filtered_rows = table.find_all(not_colspan_nine)
    date_span = 0

    for row in filtered_rows:
        cols = row.find_all('td')
        station_code = cols[0]
        station_name = cols[1]

        if date_span == 0:
            date = cols[4]
            all_sup_tags = soup.find_all('sup')
            # Remove each <sup> tag from the soup
            for sup_tag in all_sup_tags:
                sup_tag.decompose()

            if date.has_attr('rowspan'):
                # Get the value of 'colspan' attribute
                date_span = int(date['rowspan'])-1
            else:
                date_span = 0
        else:
            date_span-=1

        station_code_split = re.split(r'[\s–]+', station_code.text.strip())
        station_code_text = " | ".join(station_code_split)


        
        MRT_LRT_full_info.loc[row_num] = {"Station Code": station_code_text,
                                "Station Name": station_name.text.split("•")[0].strip(),
                                "Opening Date": date.text.strip(),
                                "Station Type": station_type}
        
        row_num+=1

# %%
MRT_LRT_full_info = MRT_LRT_full_info[(MRT_LRT_full_info['Station Code'] != '—') & (MRT_LRT_full_info['Opening Date'].str.len() > 9)]
MRT_LRT_full_info['Station Name'] = MRT_LRT_full_info['Station Name'].str.upper()

# Convert the 'date_column' to datetime objects
MRT_LRT_full_info['Opening Date'] = pd.to_datetime(MRT_LRT_full_info['Opening Date'], format='%d %B %Y')

# Keep only the row with the earliest date for each station_name
MRT_LRT_full_info = MRT_LRT_full_info.sort_values(by=['Station Name', 'Station Type', 'Opening Date'], ascending=[True, False, True])
MRT_LRT_full_info = MRT_LRT_full_info.drop_duplicates(subset=['Station Name', 'Station Type'], keep='first')

# %%
for index, row in MRT_LRT_full_info.iterrows():
    
    params['searchVal'] = row['Station Name'] + " " + row['Station Type'] + " STATION"
    # Make a GET request to the API
    response = requests.get(endpoint, params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        if response.json()['found']>0:
            data = response.json()['results'][0]
            MRT_LRT_full_info.at[index, 'Latitude'] = data['LATITUDE']
            MRT_LRT_full_info.at[index, 'Longitude'] = data['LONGITUDE']

# %%
MRT_LRT_full_info = MRT_LRT_full_info.dropna()
MRT_LRT_full_info.to_csv('MRT_LRT_full_info.csv', index=False)

# %% [markdown]
# **School Info**

# %%
response = requests.get('https://singaporeschools.fandom.com/wiki/List_of_Secondary_Schools_in_Singapore')
soup = BeautifulSoup(response.text, 'html.parser')

body = soup.find('div', id="content")
toc = body.find(id='toc')
toc.decompose()
li_elements = body.select('table')

# %%
len(li_elements)
# Out:
# 11

# %%
for li in li_elements:
    print(li.text)
# Out:
# Admiralty Secondary School
# Ahmad Ibrahim Secondary School
# Anderson Secondary School
# Ang Mo Kio Secondary School
# Balestier Hill Secondary School
# Bartley Secondary School
# Beatty Secondary School
# Bedok Green Secondary School
# Bedok North Secondary School
# Bedok South Secondary School
# Bedok Town Secondary School
# Bedok View Secondary School
# Bendemeer Secondary School
# Bishan Park Secondary School
# Boon Lay Secondary School
# Bowen Secondary School
# Broadrick Secondary School
# Bukit Batok Secondary School
# Bukit Merah Secondary School
# Bukit Panjang Govt. High School
# Bukit View Secondary School
# Canberra Secondary School
# Cedar Girls' Secondary School
# Changkat Changi Secondary School
# Chestnut Drive Secondary School
# Chong Boon Secondary School
# Chua Chu Kang Secondary School
# Clementi Town Secondary School
# Clementi Woods Secondary School
# Commonwealth Secondary School
# Compassvale Secondary School
# Coral Secondary School
# Crescent Girls' School
# Damai Secondary School
# Deyi Secondary School
# Dunearn Secondary School
# Dunman Secondary School
# East Spring Secondary School
# East View Secondary School
# Edgefield Secondary School
# Evergreen Secondary School
# Fajar Secondary School
# First Toa Payoh Secondary School
# Fuchun Secondary School
# Fuhua Secondary School
# Gan Eng Seng School
# Greendale Secondary School
# Greenridge Secondary School
# Greenview Secondary School
# Guangyang Secondary School
# Henderson Secondary School
# Hillgrove Secondary School
# Hong Kah Secondary School
# Hougang Secondary School
# Hua Yi Secondary School
# Junyuan Secondary School
# Jurong Secondary School
# Jurong West Secondary School
# Jurongville Secondary School
# Juying Secondary School
#
#
# Kent Ridge Secondary School
# Kranji Secondary School
# Loyang Secondary School
# MacPherson Secondary School
# Marsiling Secondary School
# Mayflower Secondary School
# Nan Hua High School
# Naval Base Secondary School
# New Town Secondary School
# North View Secondary School
# North Vista Secondary School
# Northbrooks Secondary School
# Northland Secondary School
# Orchid Park Secondary School
# Outram Secondary School
# Pasir Ris Crest Secondary School
# Pasir Ris Secondary School
# Pei Hwa Secondary School
# Peicai Secondary School
# Peirce Secondary School
# Ping Yi Secondary School
# Pioneer Secondary School
# Punggol Secondary School
# Queenstown Secondary School
# Queensway Secondary School
# Regent Secondary School
# Riverside Secondary School
# Sembawang Secondary School
# Seng Kang Secondary School
# Serangoon Garden Secondary School
# Serangoon Secondary School
# Shuqun Secondary School
# Si Ling Secondary School
# Siglap Secondary School
# Springfield Secondary School
# Swiss Cottage Secondary School
# Tampines Secondary School
# Tanglin Secondary School
# Tanjong Katong Girls' School
# Tanjong Katong Secondary School
# Teck Whye Secondary School
# Temasek Secondary School
# Unity Secondary School
# Victoria School
#
# Hwa Chong Institution
# Maris Stella High School
# Nan Hua High School
# Nanyang Girls' High School
# River Valley High School
#
#
#
#
# NUS High School of Mathematics and Science
# School of the Arts, Singapore
#
#
# School of Science and Technology, Singapore
# Singapore Sports School
#
#
#
#
# Cambridge Institute
#
#
# City College

# %%
columns = ['School Name', 'Longitude', 'Latitude']
schools = pd.DataFrame(columns=columns)
schools['School Name'] = list(set([li.text.split(',')[0] for li in li_elements]))

# %%
schools
# Out:
#                                            School Name Longitude Latitude
# 0                      Clementi Woods Secondary School       NaN      NaN
# 1                         Bedok North Secondary School       NaN      NaN
# 2                         Jurongville Secondary School       NaN      NaN
# 3                          Ang Mo Kio Secondary School       NaN      NaN
# 4                           Woodlands Secondary School       NaN      NaN
# 5               Fairfield Methodist School (Secondary)       NaN      NaN
# 6                           Bendemeer Secondary School       NaN      NaN
# 7                           Guangyang Secondary School       NaN      NaN
# 8             St. Anthony's Canossian Secondary School       NaN      NaN
# 9                             Tanglin Secondary School       NaN      NaN
# 10                         Holy Innocents' High School       NaN      NaN
# 11                     Tanjong Katong Secondary School       NaN      NaN
# 12                           Ngee Ann Secondary School       NaN      NaN
# 13            Temasek Junior College's Temasek Academy       NaN      NaN
# 14                    Madrasah Wak Tanjong Al-Islamiah       NaN      NaN
# 15                            St. Joseph's Institution       NaN      NaN
# 16                         Naval Base Secondary School       NaN      NaN
# 17                           Montfort Secondary School       NaN      NaN
# 18                         Bukit View Secondary School       NaN      NaN
# 19                      Clementi Town Secondary School       NaN      NaN
# 20                     CHIJ St. Nicholas Girls' School       NaN      NaN
# 21                          Marsiling Secondary School       NaN      NaN
# 22                              Damai Secondary School       NaN      NaN
# 23                                        City College       NaN      NaN
# 24                             Shuqun Secondary School       NaN      NaN
# 25                                Anglican High School       NaN      NaN
# 26                      Swiss Cottage Secondary School       NaN      NaN
# 27                         Bedok Town Secondary School       NaN      NaN
# 28                         Kent Ridge Secondary School       NaN      NaN
# 29          NUS High School of Mathematics and Science       NaN      NaN
# 30                            Bartley Secondary School       NaN      NaN
# 31                    Pasir Ris Crest Secondary School       NaN      NaN
# 32                             Singapore Sports School       NaN      NaN
# 33                            Presbyterian High School       NaN      NaN
# 34                     Madrasah Al-Arabiah Al-Islamiah       NaN      NaN
# 35                                   Northlight School       NaN      NaN
# 36                             Jurong Secondary School       NaN      NaN
# 37                           Zhonghua Secondary School       NaN      NaN
# 38                          Nanyang Girls' High School       NaN      NaN
# 39                      Ahmad Ibrahim Secondary School       NaN      NaN
# 40                          Henderson Secondary School       NaN      NaN
# 41                            Ping Yi Secondary School       NaN      NaN
# 42                           Westwood Secondary School       NaN      NaN
# 43                          East View Secondary School       NaN      NaN
# 44                              Unity Secondary School       NaN      NaN
# 45                     Woodlands Ring Secondary School       NaN      NaN
# 46                   Serangoon Garden Secondary School       NaN      NaN
# 47                        Bishan Park Secondary School       NaN      NaN
# 48                              Crescent Girls' School       NaN      NaN
# 49                Fairfield Methodist Secondary School       NaN      NaN
# 50                            Hai Sing Catholic School       NaN      NaN
# 51                            Temasek Secondary School       NaN      NaN
# 52                            River Valley High School       NaN      NaN
# 53                      Chua Chu Kang Secondary School       NaN      NaN
# 54                       Yio Chu Kang Secondary School       NaN      NaN
# 55                       Cedar Girls' Secondary School       NaN      NaN
# 56                          Teck Whye Secondary School       NaN      NaN
# 57                             Kranji Secondary School       NaN      NaN
# 58                        Bukit Merah Secondary School       NaN      NaN
# 59                          CHIJ Secondary (Toa Payoh)       NaN      NaN
# 60                          Queensway Secondary School       NaN      NaN
# 61                         MacPherson Secondary School       NaN      NaN
# 62                  Anglo-Chinese School (Barker Road)       NaN      NaN
# 63                             Hua Yi Secondary School       NaN      NaN
# 64                Geylang Methodist School (Secondary)       NaN      NaN
# 65                            Hougang Secondary School       NaN      NaN
# 66                            Maris Stella High School       NaN      NaN
# 67                               Hwa Chong Institution       NaN      NaN
# 68                           New Town Secondary School       NaN      NaN
# 69                           Zhenghua Secondary School       NaN      NaN
# 70                        Tanjong Katong Girls' School       NaN      NaN
# 71                        Bedok South Secondary School       NaN      NaN
# 72                        Compassvale Secondary School       NaN      NaN
# 73                        St. Hilda's Secondary School       NaN      NaN
# 74                            Dunearn Secondary School       NaN      NaN
# 75                                 Cambridge Institute       NaN      NaN
# 76                                 Nan Hua High School       NaN      NaN
# 77                          Serangoon Secondary School       NaN      NaN
# 78                           Manjusri Secondary School       NaN      NaN
# 79                          CHIJ St. Theresa's Convent       NaN      NaN
# 80                        Bukit Batok Secondary School       NaN      NaN
# 81                            Pei Hwa Secondary School       NaN      NaN
# 82                             National Junior College       NaN      NaN
# 83                          Pasir Ris Secondary School       NaN      NaN
# 84                             Yishun Secondary School       NaN      NaN
# 85                        North Vista Secondary School       NaN      NaN
# 86                           Anderson Secondary School       NaN      NaN
# 87                        Jurong West Secondary School       NaN      NaN
# 88                            Pioneer Secondary School       NaN      NaN
# 89                                Catholic High School       NaN      NaN
# 90                          Hillgrove Secondary School       NaN      NaN
# 91   Raffles Girls' School (Secondary) / Raffles In...       NaN      NaN
# 92                             Outram Secondary School       NaN      NaN
# 93                             Beatty Secondary School       NaN      NaN
# 94                             Juying Secondary School       NaN      NaN
# 95                            Punggol Secondary School       NaN      NaN
# 96                      Madrasah Al-Irsyad Al-Islamiah       NaN      NaN
# 97                           CHIJ St. Joseph's Convent       NaN      NaN
# 98                    School of Science and Technology       NaN      NaN
# 99                             Fuchun Secondary School       NaN      NaN
# 100                             Fuhua Secondary School       NaN      NaN
# 101                          Assumption English School       NaN      NaN
# 102                         Evergreen Secondary School       NaN      NaN
# 103                         Seng Kang Secondary School       NaN      NaN
# 104                      Commonwealth Secondary School       NaN      NaN
# 105                         Admiralty Secondary School       NaN      NaN
# 106                                 School of the Arts       NaN      NaN
# 107                     Chung Cheng High School (Main)       NaN      NaN
# 108                 Anglo-Chinese School (Independent)       NaN      NaN
# 109                          Hong Kah Secondary School       NaN      NaN
# 110                        Queenstown Secondary School       NaN      NaN
# 111                        North View Secondary School       NaN      NaN
# 112                   Chung Cheng High School (Yishun)       NaN      NaN
# 113                                    Victoria School       NaN      NaN
# 114                            Peicai Secondary School       NaN      NaN
# 115                       Springfield Secondary School       NaN      NaN
# 116                      St. Andrew's Secondary School       NaN      NaN
# 117                          Canberra Secondary School       NaN      NaN
# 118                       West Spring Secondary School       NaN      NaN
# 119                      Madrasah Aljunied Al-Islamiah       NaN      NaN
# 120                       Yishun Town Secondary School       NaN      NaN
# 121                       Bedok Green Secondary School       NaN      NaN
# 122                            Xinmin Secondary School       NaN      NaN
# 123                         Edgefield Secondary School       NaN      NaN
# 124                            Peirce Secondary School       NaN      NaN
# 125     Paya Lebar Methodist Girls' School (Secondary)       NaN      NaN
# 126                         Sembawang Secondary School       NaN      NaN
# 127                             Bowen Secondary School       NaN      NaN
# 128                          Tampines Secondary School       NaN      NaN
# 129                       Northbrooks Secondary School       NaN      NaN
# 130                     Christ Church Secondary School       NaN      NaN
# 131                             Yuhua Secondary School       NaN      NaN
# 132                           Whitley Secondary School       NaN      NaN
# 133                        Bedok View Secondary School       NaN      NaN
# 134                    Bukit Panjang Govt. High School       NaN      NaN
# 135            Kuo Chuan Presbyterian Secondary School       NaN      NaN
# 136                                CHIJ Katong Convent       NaN      NaN
# 137                     Madrasah Al-Maarif Al-Islamiah       NaN      NaN
# 138                            Victoria Junior College       NaN      NaN
# 139                                Raffles Institution       NaN      NaN
# 140                    Singapore Chinese Girls' School       NaN      NaN
# 141                           Junyuan Secondary School       NaN      NaN
# 142                       Yusof Ishak Secondary School       NaN      NaN
# 143                            Yuying Secondary School       NaN      NaN
# 144                             Coral Secondary School       NaN      NaN
# 145                        Chong Boon Secondary School       NaN      NaN
# 146                    Balestier Hill Secondary School       NaN      NaN
# 147                             Fajar Secondary School       NaN      NaN
# 148                      Madrasah Alsagoff Al-Islamiah       NaN      NaN
# 149                Methodist Girls' School (Secondary)       NaN      NaN
# 150                          Boon Lay Secondary School       NaN      NaN
# 151                  Raffles Girls' School (Secondary)       NaN      NaN
# 152                         Broadrick Secondary School       NaN      NaN
# 153                                Gan Eng Seng School       NaN      NaN
# 154                            Regent Secondary School       NaN      NaN
# 155                        Yuan Ching Secondary School       NaN      NaN
# 156                         Greendale Secondary School       NaN      NaN
# 157                                 Dunman High School       NaN      NaN
# 158                     St. Gabriel's Secondary School       NaN      NaN
# 159                         Greenview Secondary School       NaN      NaN
# 160                           Si Ling Secondary School       NaN      NaN
# 161                   First Toa Payoh Secondary School       NaN      NaN
# 162                              Nan Chiau High School       NaN      NaN
# 163                            Loyang Secondary School       NaN      NaN
# 164                        Greenridge Secondary School       NaN      NaN
# 165                   Changkat Changi Secondary School       NaN      NaN
# 166                         Northland Secondary School       NaN      NaN
# 167                         Woodgrove Secondary School       NaN      NaN
# 168                              Deyi Secondary School       NaN      NaN
# 169                            Dunman Secondary School       NaN      NaN
# 170                       Orchid Park Secondary School       NaN      NaN
# 171                    St. Margaret's Secondary School       NaN      NaN
# 172                               St. Patrick's School       NaN      NaN
# 173                            Siglap Secondary School       NaN      NaN
# 174                         Riverside Secondary School       NaN      NaN
# 175                    Chestnut Drive Secondary School       NaN      NaN
# 176                       East Spring Secondary School       NaN      NaN
# 177                         Mayflower Secondary School       NaN      NaN

# %%
for index,row in schools.iterrows():
    params['searchVal'] = row['School Name']
    # Make a GET request to the API
    response = requests.get(endpoint, params=params)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        if response.json()['found']>0:
            data = response.json()['results'][0]
            schools.at[index, 'Latitude'] = data['LATITUDE']
            schools.at[index, 'Longitude'] = data['LONGITUDE']

# %%
schools
# Out:
#                                            School Name         Longitude  \
# 0                      Clementi Woods Secondary School               NaN
# 1                         Bedok North Secondary School  103.941977166932
# 2                         Jurongville Secondary School  103.728907710089
# 3                          Ang Mo Kio Secondary School  103.842154973672
# 4                           Woodlands Secondary School  103.800148469692
# 5               Fairfield Methodist School (Secondary)  103.784099647149
# 6                           Bendemeer Secondary School  103.860518349544
# 7                           Guangyang Secondary School  103.850208933626
# 8             St. Anthony's Canossian Secondary School  103.941977166932
# 9                             Tanglin Secondary School  103.758158358303
# 10                         Holy Innocents' High School  103.896398814264
# 11                     Tanjong Katong Secondary School  103.897225196199
# 12                           Ngee Ann Secondary School  103.956747262496
# 13            Temasek Junior College's Temasek Academy               NaN
# 14                    Madrasah Wak Tanjong Al-Islamiah  103.891260934228
# 15                            St. Joseph's Institution  103.845611935235
# 16                         Naval Base Secondary School  103.831050390247
# 17                           Montfort Secondary School  103.888928372577
# 18                         Bukit View Secondary School  103.752226593984
# 19                      Clementi Town Secondary School  103.762020598524
# 20                     CHIJ St. Nicholas Girls' School  103.834253269436
# 21                          Marsiling Secondary School  103.776008090454
# 22                              Damai Secondary School  103.927091653438
# 23                                        City College  103.840603664795
# 24                             Shuqun Secondary School               NaN
# 25                                Anglican High School  103.941853465631
# 26                      Swiss Cottage Secondary School  103.750396136688
# 27                         Bedok Town Secondary School               NaN
# 28                         Kent Ridge Secondary School  103.764889617566
# 29          NUS High School of Mathematics and Science  103.769365156929
# 30                            Bartley Secondary School  103.882806211705
# 31                    Pasir Ris Crest Secondary School  103.959728202919
# 32                             Singapore Sports School  103.789444793951
# 33                            Presbyterian High School  103.843149382823
# 34                     Madrasah Al-Arabiah Al-Islamiah   103.85470673847
# 35                                   Northlight School   103.85575955353
# 36                             Jurong Secondary School  103.723952961648
# 37                           Zhonghua Secondary School  103.869430481414
# 38                          Nanyang Girls' High School  103.802420979943
# 39                      Ahmad Ibrahim Secondary School  103.829718690077
# 40                          Henderson Secondary School               NaN
# 41                            Ping Yi Secondary School  103.920700671987
# 42                           Westwood Secondary School  103.701772102139
# 43                          East View Secondary School               NaN
# 44                              Unity Secondary School   103.74602091483
# 45                     Woodlands Ring Secondary School  103.800148469692
# 46                   Serangoon Garden Secondary School  103.869270301476
# 47                        Bishan Park Secondary School               NaN
# 48                              Crescent Girls' School  103.817544461755
# 49                Fairfield Methodist Secondary School  103.784099647149
# 50                            Hai Sing Catholic School  103.954957944437
# 51                            Temasek Secondary School  103.947564112022
# 52                            River Valley High School  103.709022156436
# 144               NaN
# 145               NaN
# 146               NaN
# 147               NaN
# 148               NaN
# 149  1.35096755912522
# 150  1.34272216334333
# 151  1.34217479932295
# 152  1.30705061123433
# 153  1.28907114485773
# 154  1.39327908335682
# 155  1.34200635764467
# 156  1.39696019936894
# 157  1.29996216014962
# 158  1.34648798732177
# 159               NaN
# 160               NaN
# 161               NaN
# 162  1.38879582498399
# 163  1.36658417167238
# 164    1.375600053443
# 165  1.33950630072876
# 166  1.43580183362637
# 167  1.42831828137013
# 168  1.36599702567717
# 169  1.36065258337022
# 170  1.41532032779634
# 171  1.32006821363359
# 172  1.30788341871801
# 173               NaN
# 174  1.44110157139127
# 175               NaN
# 176  1.35622508992581
# 177  1.36827266209722

# %%
schools[schools.isna().any(axis=1)]
# Out:
#                                            School Name Longitude Latitude
# 0                      Clementi Woods Secondary School       NaN      NaN
# 13            Temasek Junior College's Temasek Academy       NaN      NaN
# 24                             Shuqun Secondary School       NaN      NaN
# 27                         Bedok Town Secondary School       NaN      NaN
# 40                          Henderson Secondary School       NaN      NaN
# 43                          East View Secondary School       NaN      NaN
# 47                        Bishan Park Secondary School       NaN      NaN
# 61                         MacPherson Secondary School       NaN      NaN
# 75                                 Cambridge Institute       NaN      NaN
# 88                            Pioneer Secondary School       NaN      NaN
# 91   Raffles Girls' School (Secondary) / Raffles In...       NaN      NaN
# 111                        North View Secondary School       NaN      NaN
# 137                     Madrasah Al-Maarif Al-Islamiah       NaN      NaN
# 144                             Coral Secondary School       NaN      NaN
# 145                        Chong Boon Secondary School       NaN      NaN
# 146                    Balestier Hill Secondary School       NaN      NaN
# 147                             Fajar Secondary School       NaN      NaN
# 148                      Madrasah Alsagoff Al-Islamiah       NaN      NaN
# 159                         Greenview Secondary School       NaN      NaN
# 160                           Si Ling Secondary School       NaN      NaN
# 161                   First Toa Payoh Secondary School       NaN      NaN
# 173                            Siglap Secondary School       NaN      NaN
# 175                    Chestnut Drive Secondary School       NaN      NaN

# %%
params = {
    'returnGeom': 'Y',
    'getAddrDetails': 'Y',
    'token': api_token,
    'searchVal': '248649'
}


response = requests.get(endpoint, params=params)

if response.status_code == 200:
    print(response.json()['results'])
# Out:
# [{'SEARCHVAL': 'CAMDEN CENTRE', 'BLK_NO': '1', 'ROAD_NAME': 'ORCHARD BOULEVARD', 'BUILDING': 'CAMDEN CENTRE', 'ADDRESS': '1 ORCHARD BOULEVARD CAMDEN CENTRE SINGAPORE 248649', 'POSTAL': '248649', 'X': '26952.5940440893', 'Y': '31719.8530864734', 'LATITUDE': '1.30313758150045', 'LONGITUDE': '103.823907153629'}, {'SEARCHVAL': 'CAMDEN MEDICAL CENTRE', 'BLK_NO': '1', 'ROAD_NAME': 'ORCHARD BOULEVARD', 'BUILDING': 'CAMDEN MEDICAL CENTRE', 'ADDRESS': '1 ORCHARD BOULEVARD CAMDEN MEDICAL CENTRE SINGAPORE 248649', 'POSTAL': '248649', 'X': '26990.9680057215', 'Y': '31744.7634857334', 'LATITUDE': '1.30336286364963', 'LONGITUDE': '103.824251960562'}]
