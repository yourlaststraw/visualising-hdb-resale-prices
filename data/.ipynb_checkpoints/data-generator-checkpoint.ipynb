# %%
import numpy as np
import pandas as pd

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')

df
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 174990  2024-03      YISHUN     5 ROOM   607       YISHUN ST 61     01 TO 03
# 174991  2024-03      YISHUN     5 ROOM   841       YISHUN ST 81     07 TO 09
# 174992  2024-03      YISHUN  EXECUTIVE   344      YISHUN AVE 11     01 TO 03
# 174993  2024-03      YISHUN  EXECUTIVE   791       YISHUN AVE 2     10 TO 12
# 174994  2024-03      YISHUN  EXECUTIVE   606       YISHUN ST 61     07 TO 09
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 0                 44.0        Improved                 1979
# 1                 67.0  New Generation                 1978
# 2                 67.0  New Generation                 1980
# 3                 68.0  New Generation                 1980
# 4                 67.0  New Generation                 1980
# ...                ...             ...                  ...
# 174990           121.0        Improved                 1987
# 174991           122.0        Improved                 1988
# 174992           145.0      Maisonette                 1988
# 174993           146.0       Apartment                 1987
# 174994           142.0       Apartment                 1987
#
#            remaining_lease  resale_price
# 0       61 years 04 months      232000.0
# 1       60 years 07 months      250000.0
# 2       62 years 05 months      262000.0
# 3        62 years 01 month      265000.0
# 4       62 years 05 months      265000.0
# ...                    ...           ...
# 174990  62 years 07 months      613000.0
# 174991  62 years 11 months      745000.0
# 174992  63 years 05 months      820000.0
# 174993  62 years 07 months      851888.0
# 174994  62 years 10 months      780000.0
#
# [174995 rows x 11 columns]
